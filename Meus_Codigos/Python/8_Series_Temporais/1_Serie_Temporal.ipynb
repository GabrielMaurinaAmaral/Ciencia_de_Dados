# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from datetime import datetime

#registro de converters para uso do matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
base = pd.read_csv('AirPassengers.csv')
base.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
base.dtypes
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
# Conversão dos atributos que estão no formato string para formato de data: ANO-MÊS
dateparse = lambda dates: datetime.strptime(dates, '%Y-%m')

base = pd.read_csv('AirPassengers.csv', parse_dates = ['Month'],
                   index_col = 'Month', date_parser = dateparse)
base
# Out:
# C:\Users\GABRIEL\AppData\Local\Temp\ipykernel_29876\347101161.py:4: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   base = pd.read_csv('AirPassengers.csv', parse_dates = ['Month'],
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
# Visualização do índice do dataframe (#Passengers) 
base.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
#criação da série temporal (ts)
ts = base['#Passengers']
ts
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: #Passengers, Length: 144, dtype: int64

# %%
# Visualização por ano e mês
ts['1949-02']
# Out:
# Month
# 1949-02-01    118
# Name: #Passengers, dtype: int64

# %%
# Visualização de data específica
ts[datetime(1949,2,1)]
# Out:
# 118

# %%
# Visualização de intervalos
ts['1950-01-01':'1950-07-31']
# Out:
# Month
# 1950-01-01    115
# 1950-02-01    126
# 1950-03-01    141
# 1950-04-01    135
# 1950-05-01    125
# 1950-06-01    149
# 1950-07-01    170
# Name: #Passengers, dtype: int64

# %%
# Visualização de intervalos sem preencher a data de início
ts[:'1950-07-31']
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# 1949-07-01    148
# 1949-08-01    148
# 1949-09-01    136
# 1949-10-01    119
# 1949-11-01    104
# 1949-12-01    118
# 1950-01-01    115
# 1950-02-01    126
# 1950-03-01    141
# 1950-04-01    135
# 1950-05-01    125
# 1950-06-01    149
# 1950-07-01    170
# Name: #Passengers, dtype: int64

# %%
# Visualização por ano
ts['1950']
# Out:
# Month
# 1950-01-01    115
# 1950-02-01    126
# 1950-03-01    141
# 1950-04-01    135
# 1950-05-01    125
# 1950-06-01    149
# 1950-07-01    170
# 1950-08-01    170
# 1950-09-01    158
# 1950-10-01    133
# 1950-11-01    114
# 1950-12-01    140
# Name: #Passengers, dtype: int64

# %%
# Valores máximos 
ts.index.max()
# Out:
# Timestamp('1960-12-01 00:00:00')

# %%
# mínimos
ts.index.min()
# Out:
# Timestamp('1949-01-01 00:00:00')

# %%
plt.plot(ts)

# %%
# Visualização por ano
ts_ano = ts.resample('A').sum()

plt.plot(ts_ano)
ts_ano
# Out:
# Month
# 1949-12-31    1520
# 1950-12-31    1676
# 1951-12-31    2042
# 1952-12-31    2364
# 1953-12-31    2700
# 1954-12-31    2867
# 1955-12-31    3408
# 1956-12-31    3939
# 1957-12-31    4421
# 1958-12-31    4572
# 1959-12-31    5140
# 1960-12-31    5714
# Freq: A-DEC, Name: #Passengers, dtype: int64

# %%
# Visualização por mês
ts_mes = ts.groupby([lambda x: x.month]).sum()

plt.plot(ts_mes)
ts_mes
# Out:
# Month
# 1     2901
# 2     2820
# 3     3242
# 4     3205
# 5     3262
# 6     3740
# 7     4216
# 8     4213
# 9     3629
# 10    3199
# 11    2794
# 12    3142
# Name: #Passengers, dtype: int64

# %%
ts_datas = ts['1960-01-01':'1960-12-01']
plt.plot(ts_datas)
