# %% [markdown]
# # Distribuição T Student

# %%
from scipy.stats import t

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('t_student.png')
plt.imshow(img)
plt.axis('off') 
plt.show()

# %% [markdown]
# Média de salário dos cientistas de dados = R$ 75,00 por hora
# Amostra com 9 funcionários e desvio padrão = 10

# %%
# probabilidade de selecionar um cientista de dados e o salário ser menor que R$ 80 por hora
t.cdf(1.5, 8)
# Out:
# 0.9139983540240443

# %%
# probabilidade do salário ser maior do que 80?
t.sf(1.5, 8)
# Out:
# 0.08600164597595565

# %%
# Somatório da execução dos dois códigos acima (lado esquerdo + lado direito da distribuição)
t.cdf(1.5, 8) + t.sf(1.5, 8)
# Out:
# 0.9999999999999999
